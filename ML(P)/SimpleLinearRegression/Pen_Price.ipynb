# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# 2. Load dataset
df = pd.read_csv("pen_price.csv")
df
# Out:
#    S.No  pen  price
# 0     0    5     25
# 1     1    3     17
# 2     2   20     95
# 3     3   10     55
# 4     4    9     45
# 5     5   12     58
# 6     6   17     80
# 7     7   14     67
# 8     8    8     45
# 9     9    6     32

# %%
df=df[["pen", "price"]]
df
# Out:
#    pen  price
# 0    5     25
# 1    3     17
# 2   20     95
# 3   10     55
# 4    9     45
# 5   12     58
# 6   17     80
# 7   14     67
# 8    8     45
# 9    6     32

# %%
# 3. Basic Exploratory Data Analysis (EDA)
print(df.info(), df.describe(), sep="\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pen     10 non-null     int64
#  1   price   10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes
# None
#              pen      price
# count  10.000000  10.000000
# mean   10.400000  51.900000
# std     5.399588  24.392394
# min     3.000000  17.000000
# 25%     6.500000  35.250000
# 50%     9.500000  50.000000
# 75%    13.500000  64.750000
# max    20.000000  95.000000

# %%
# 4. Define input (X) & output (y)
x = df[["pen"]]
y = df["price"]

# %%
x
# Out:
#    pen
# 0    5
# 1    3
# 2   20
# 3   10
# 4    9
# 5   12
# 6   17
# 7   14
# 8    8
# 9    6

# %%
y
# Out:
# 0    25
# 1    17
# 2    95
# 3    55
# 4    45
# 5    58
# 6    80
# 7    67
# 8    45
# 9    32
# Name: price, dtype: int64

# %%
# 5. Split data into training and testing sets
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
# 6. Define and train the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 7. Predict output
y_pred = model.predict(x_test)
y_pred
# Out:
# array([40.94201807, 18.46084337, 58.92695783])

# %%
y_test
# Out:
# 8    45
# 1    17
# 5    58
# Name: price, dtype: int64

# %%
# 8. Evaluate model performance
r2_score(y_test, y_pred)
# Out:
# 0.977835385525553

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2.1485943775100425

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 6.486843836188129

# %%
# 9. Visualize results
plt.scatter(x_test, y_test, color="red", label="Actual")
plt.scatter(x_test, y_pred, color="green", label="Predicted")
plt.plot(x_test, y_pred, color="blue")
plt.legend()
plt.show()
